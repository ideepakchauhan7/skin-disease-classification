# %%
# !pip install kaggle
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kaggle in c:\programdata\miniconda3\envs\tf\lib\site-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in c:\programdata\miniconda3\envs\tf\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in c:\programdata\miniconda3\envs\tf\lib\site-packages (from kaggle) (2024.7.4)
# Requirement already satisfied: python-dateutil in c:\programdata\miniconda3\envs\tf\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in c:\programdata\miniconda3\envs\tf\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in c:\programdata\miniconda3\envs\tf\lib\site-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in c:\programdata\miniconda3\envs\tf\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in c:\programdata\miniconda3\envs\tf\lib\site-packages (from kaggle) (2.2.2)
# Requirement already satisfied: bleach in c:\programdata\miniconda3\envs\tf\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: packaging in c:\programdata\miniconda3\envs\tf\lib\site-packages (from bleach->kaggle) (24.1)
# Requirement already satisfied: webencodings in c:\programdata\miniconda3\envs\tf\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\programdata\miniconda3\envs\tf\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\miniconda3\envs\tf\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\miniconda3\envs\tf\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: colorama in c:\programdata\miniconda3\envs\tf\lib\site-packages (from tqdm->kaggle) (0.4.6)

# %%
! kaggle datasets download shubhamgoel27/dermnet
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shubhamgoel27/dermnet
# License(s): Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)
# dermnet.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

# %%
with zipfile.ZipFile("dermnet.zip","r") as f:
    f.extractall("")

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 64
IMAGE_SIZE = 128
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "train",
    shuffle = True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE 
)
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "test",
    shuffle = True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE  
)
# Out:
# Found 15557 files belonging to 23 classes.
# Found 4002 files belonging to 23 classes.

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Acne and Rosacea Photos',
#  'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions',
#  'Atopic Dermatitis Photos',
#  'Bullous Disease Photos',
#  'Cellulitis Impetigo and other Bacterial Infections',
#  'Eczema Photos',
#  'Exanthems and Drug Eruptions',
#  'Hair Loss Photos Alopecia and other Hair Diseases',
#  'Herpes HPV and other STDs Photos',
#  'Light Diseases and Disorders of Pigmentation',
#  'Lupus and other Connective Tissue diseases',
#  'Melanoma Skin Cancer Nevi and Moles',
#  'Nail Fungus and other Nail Disease',
#  'Poison Ivy Photos and other Contact Dermatitis',
#  'Psoriasis pictures Lichen Planus and related diseases',
#  'Scabies Lyme Disease and other Infestations and Bites',
#  'Seborrheic Keratoses and other Benign Tumors',
#  'Systemic Disease',
#  'Tinea Ringworm Candidiasis and other Fungal Infections',
#  'Urticaria Hives',
#  'Vascular Tumors',
#  'Vasculitis Photos',
#  'Warts Molluscum and other Viral Infections']

# %%
plt.figure(figsize = (15,15))
for image_batch, label_batch in train_dataset.take(1):
  for i in range(2):
     ax = plt.subplot(3,4,i+1)
     plt.imshow(image_batch[i].numpy().astype("uint8"))
     plt.title(class_names[label_batch[i]],fontsize = 8)
     plt.axis("off")

# %%
def get_dataset_partitions_tf(ds, train_split = 0.8,val_split = 0.2,shuffle = True,shuffle_size = 10000):
  assert(train_split+val_split) == 1
  ds_size = len(ds)
  if shuffle:
    ds = ds.shuffle(shuffle_size, seed = 12)
  train_size = int(train_split*ds_size)
  val_size = int(val_split * ds_size)

  train_ds = ds.take(train_size)
  val_ds = ds.skip(train_size).take(val_size)
  return train_ds, val_ds

# %%
train_ds, val_ds = get_dataset_partitions_tf(train_dataset)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
                     layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
                     layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
model = models.Sequential([
                           resize_and_rescale,
                           layers.Conv2D(64, kernel_size = (3,3), activation = 'relu', input_shape = (BATCH_SIZE,IMAGE_SIZE,IMAGE_SIZE,3) ),
                           layers.MaxPooling2D((2,2)),
                           layers.Conv2D(128, kernel_size = (3,3), activation = 'relu'),
                           layers.MaxPooling2D((2,2)), 
                           layers.Conv2D(128, kernel_size = (3,3), activation = 'relu'),
                           layers.MaxPooling2D((2,2)),    
                           layers.Conv2D(128, (3, 3), activation='relu'),
                           layers.MaxPooling2D((2, 2)),
                           layers.Conv2D(128, (3, 3), activation='relu'),
                           layers.MaxPooling2D((2, 2)),    
                           layers.Flatten(),
                           layers.Dense(128, activation='relu'),
                           layers.Dense(23, activation='softmax')
])
model.build(input_shape = (BATCH_SIZE,128,128,3))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (64, 128, 128, 3)         0
#
#  conv2d (Conv2D)             (64, 126, 126, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (64, 63, 63, 64)         0
#  )
#
#  conv2d_1 (Conv2D)           (64, 61, 61, 128)         73856
#
#  max_pooling2d_1 (MaxPooling  (64, 30, 30, 128)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (64, 28, 28, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (64, 14, 14, 128)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (64, 12, 12, 128)         147584
#
#  max_pooling2d_3 (MaxPooling  (64, 6, 6, 128)          0
#  2D)
#
#  conv2d_4 (Conv2D)           (64, 4, 4, 128)           147584
#
#  max_pooling2d_4 (MaxPooling  (64, 2, 2, 128)          0
#  2D)
#
#  flatten (Flatten)           (64, 512)                 0
#
#  dense (Dense)               (64, 128)                 65664
#
#  dense_1 (Dense)             (64, 23)                  2967
#
# =================================================================
# Total params: 587,031
# Trainable params: 587,031
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
EPOCHS = 30
history = model.fit(
    train_ds,
    epochs = EPOCHS,
    batch_size = BATCH_SIZE,
    validation_data = val_ds,
    verbose = 1,
)
# Out:
# Epoch 1/30
# 195/195 [==============================] - 35s 84ms/step - loss: 2.9683 - accuracy: 0.1012 - val_loss: 2.8836 - val_accuracy: 0.1465
# Epoch 2/30
# 195/195 [==============================] - 16s 83ms/step - loss: 2.8495 - accuracy: 0.1606 - val_loss: 2.8015 - val_accuracy: 0.1742
# Epoch 3/30
# 195/195 [==============================] - 15s 78ms/step - loss: 2.7673 - accuracy: 0.1852 - val_loss: 2.7030 - val_accuracy: 0.1985
# Epoch 4/30
# 195/195 [==============================] - 15s 77ms/step - loss: 2.6813 - accuracy: 0.2071 - val_loss: 2.6321 - val_accuracy: 0.2157
# Epoch 5/30
# 195/195 [==============================] - 15s 77ms/step - loss: 2.6007 - accuracy: 0.2282 - val_loss: 2.5528 - val_accuracy: 0.2376
# Epoch 6/30
# 195/195 [==============================] - 15s 77ms/step - loss: 2.5269 - accuracy: 0.2452 - val_loss: 2.4652 - val_accuracy: 0.2663
# Epoch 7/30
# 195/195 [==============================] - 15s 77ms/step - loss: 2.4491 - accuracy: 0.2723 - val_loss: 2.3790 - val_accuracy: 0.2943
# Epoch 8/30
# 195/195 [==============================] - 15s 77ms/step - loss: 2.3613 - accuracy: 0.2920 - val_loss: 2.2653 - val_accuracy: 0.3281
# Epoch 9/30
# 195/195 [==============================] - 15s 77ms/step - loss: 2.2540 - accuracy: 0.3249 - val_loss: 2.2246 - val_accuracy: 0.3359
# Epoch 10/30
# 195/195 [==============================] - 15s 78ms/step - loss: 2.1461 - accuracy: 0.3517 - val_loss: 2.1031 - val_accuracy: 0.3770
# Epoch 11/30
# 195/195 [==============================] - 15s 76ms/step - loss: 2.0336 - accuracy: 0.3859 - val_loss: 2.0254 - val_accuracy: 0.4036
# Epoch 12/30
# 195/195 [==============================] - 15s 77ms/step - loss: 1.9150 - accuracy: 0.4199 - val_loss: 1.9182 - val_accuracy: 0.4447
# Epoch 13/30
# 195/195 [==============================] - 15s 76ms/step - loss: 1.7752 - accuracy: 0.4608 - val_loss: 1.8884 - val_accuracy: 0.4639
# Epoch 14/30
# 195/195 [==============================] - 15s 78ms/step - loss: 1.6593 - accuracy: 0.4975 - val_loss: 1.7862 - val_accuracy: 0.4870
# Epoch 15/30
# 195/195 [==============================] - 15s 79ms/step - loss: 1.5293 - accuracy: 0.5324 - val_loss: 1.7391 - val_accuracy: 0.5153
# Epoch 16/30
# 195/195 [==============================] - 15s 79ms/step - loss: 1.3924 - accuracy: 0.5737 - val_loss: 1.6854 - val_accuracy: 0.5534
# Epoch 17/30
# 195/195 [==============================] - 16s 80ms/step - loss: 1.2872 - accuracy: 0.6051 - val_loss: 1.6442 - val_accuracy: 0.5820
# Epoch 18/30
# 195/195 [==============================] - 15s 79ms/step - loss: 1.1852 - accuracy: 0.6355 - val_loss: 1.6106 - val_accuracy: 0.5960
# Epoch 19/30
# 195/195 [==============================] - 15s 78ms/step - loss: 1.0635 - accuracy: 0.6722 - val_loss: 1.4747 - val_accuracy: 0.6491
# Epoch 20/30
# 195/195 [==============================] - 15s 78ms/step - loss: 0.9854 - accuracy: 0.6933 - val_loss: 1.4997 - val_accuracy: 0.6559
# Epoch 21/30
# 195/195 [==============================] - 16s 83ms/step - loss: 0.9123 - accuracy: 0.7159 - val_loss: 1.4916 - val_accuracy: 0.6823
# Epoch 22/30
# 195/195 [==============================] - 22s 115ms/step - loss: 0.8272 - accuracy: 0.7395 - val_loss: 1.4400 - val_accuracy: 0.6725
# Epoch 23/30
# 195/195 [==============================] - 22s 114ms/step - loss: 0.7428 - accuracy: 0.7681 - val_loss: 1.3996 - val_accuracy: 0.7096
# Epoch 24/30
# 195/195 [==============================] - 22s 113ms/step - loss: 0.6967 - accuracy: 0.7845 - val_loss: 1.5760 - val_accuracy: 0.7106
# Epoch 25/30
# 195/195 [==============================] - 22s 113ms/step - loss: 0.6419 - accuracy: 0.7990 - val_loss: 1.5669 - val_accuracy: 0.7311
# Epoch 26/30
# 195/195 [==============================] - 21s 109ms/step - loss: 0.5821 - accuracy: 0.8170 - val_loss: 1.4818 - val_accuracy: 0.7461
# Epoch 27/30
# 195/195 [==============================] - 21s 107ms/step - loss: 0.5393 - accuracy: 0.8339 - val_loss: 1.5682 - val_accuracy: 0.7682
# Epoch 28/30
# 195/195 [==============================] - 23s 120ms/step - loss: 0.5042 - accuracy: 0.8420 - val_loss: 1.6611 - val_accuracy: 0.7350
# Epoch 29/30
# 195/195 [==============================] - 23s 121ms/step - loss: 0.4812 - accuracy: 0.8469 - val_loss: 1.6277 - val_accuracy: 0.7526
# Epoch 30/30
# 195/195 [==============================] - 23s 117ms/step - loss: 0.4585 - accuracy: 0.8557 - val_loss: 1.6816 - val_accuracy: 0.7542

# %%
import pickle
filename= 'skin_disease_classification.pkl'

# %%
pickle.dump(model,open(filename,'wb'))
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://fedc4ce8-6a73-4230-a977-6c8ad1bc363c/assets
# INFO:tensorflow:Assets written to: ram://fedc4ce8-6a73-4230-a977-6c8ad1bc363c/assets

# %%
from tensorflow.keras.models import model_from_json
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.weights.h5")

# %%
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.weights.h5")

# %%
loaded_model.predict(test_dataset)
# Out:
# 63/63 [==============================] - 5s 70ms/step
# array([[1.2369869e-01, 2.8078356e-03, 1.6268486e-02, ..., 1.5449246e-03,
#         1.6688138e-02, 5.7368791e-01],
#        [2.1274416e-02, 2.8396994e-03, 9.4419084e-03, ..., 4.1729486e-06,
#         2.5471060e-03, 4.9225651e-02],
#        [2.8043193e-01, 1.6278526e-02, 7.9003736e-02, ..., 1.5315432e-02,
#         3.2646626e-02, 7.0562892e-02],
#        ...,
#        [1.3935479e-06, 3.5099874e-04, 4.5679105e-04, ..., 3.3713022e-11,
#         8.1386983e-02, 3.7108015e-04],
#        [1.8640812e-02, 1.3074226e-04, 1.6467070e-02, ..., 9.7699147e-03,
#         1.4824070e-04, 9.2535742e-02],
#        [3.0883148e-03, 2.8963897e-05, 8.8606000e-02, ..., 2.9868810e-03,
#         7.1062263e-06, 7.0305970e-03]], dtype=float32)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(3):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
